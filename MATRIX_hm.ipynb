# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
#Playing X-O with Guest

# %%
l = [["_","_","_"],
     ["_","_","_"],
     ["_","_","_"]]
board = np.array(l)

k = 1
while k > 0: 
    k = 0

    print(board)
    print("you are [x]")
    playerx_i = eval(input("select the row: "))
    playerx_j = eval(input("select the column: "))

    if board[playerx_i-1][playerx_j-1] == "_":
        board[playerx_i-1][playerx_j-1] = "x"
    else:
        playerxx_i = playerx_i
        playerxx_j = playerx_j
        while board[playerxx_i-1][playerxx_j-1] != "_":
            print("you can not put this here!")
            print(board)
            playerxx_i = eval(input("select another row: "))
            playerxx_j = eval(input("select another column: "))
            if board[playerxx_i-1][playerxx_j-1] == "_":
                board[playerxx_i-1][playerxx_j-1] = "x"
                break
    
    if board[0][0] == "x" and board[1][0] == "x" and board[2][0] == "x":
        print(board)
        print("player x is the winner!!!!")
        break
    if board[0][1] == "x" and board[1][1] == "x" and board[2][1] == "x":
        print(board)
        print("player x is the winner!!!!")
        break
    if board[0][2] == "x" and board[1][2] == "x" and board[2][2] == "x":
        print(board)
        print("player x is the winner!!!!")
        break
    if board[0][0] == "x" and board[0][1] == "x" and board[0][2] == "x":
        print(board)
        print("player x is the winner!!!!")
        break
    if board[1][0] == "x" and board[1][1] == "x" and board[1][2] == "x":
        print(board)
        print("player x is the winner!!!!")
        break
    if board[2][0] == "x" and board[2][1] == "x" and board[2][2] == "x":
        print(board)
        print("player x is the winner!!!!")
        break

    if board[0][2] == "x" and board[1][1] == "x" and board[2][0] == "x":
        print(board)
        print("player x is the winner!!!!")
        break
    f = 0
    for i in range(3):
        if board[i-1][i-1] == "x":
            f += 1
    if f == 3:
        print(board)
        print("player x is the winner!!!!")
        break
    else:
        f = 0

    for i in range(3):
      for j in range(3):
         if board[i][j] == "_":
            k += 1
    if k == 0:
        print(board)
        print("! DRAW !")
        break
    
    print(board)
    print("you are [o]")
    playero_i = eval(input("select the row: "))
    playero_j = eval(input("select the column: "))

    if board[playero_i-1][playero_j-1] == "_":
        board[playero_i-1][playero_j-1] = "o"
    else:
        playeroo_i = playero_i
        playeroo_j = playero_j
        while board[playeroo_i-1][playeroo_j-1] != "_":
            print("you can not put this here!")
            print(board)
            playeroo_i = eval(input("select another row: "))
            playeroo_j = eval(input("select another column: "))
            if board[playeroo_i-1][playeroo_j-1] == "_":
                board[playeroo_i-1][playeroo_j-1] = "o"
                break
                

    
    if board[0][0] == "o" and board[1][0] == "o" and board[2][0] == "o":
        print(board)
        print("player o is the winner!!!!")
        break
    if board[0][1] == "o" and board[1][1] == "o" and board[2][1] == "o":
        print(board)
        print("player o is the winner!!!!")
        break
    if board[0][2] == "o" and board[1][2] == "o" and board[2][2] == "o":
        print(board)
        print("player o is the winner!!!!")
        break
    if board[0][0] == "o" and board[0][1] == "o" and board[0][2] == "o":
        print(board)
        print("player o is the winner!!!!")
        break
    if board[1][0] == "o" and board[1][1] == "o" and board[1][2] == "o":
        print(board)
        print("player o is the winner!!!!")
        break
    if board[2][0] == "o" and board[2][1] == "o" and board[2][2] == "o":
        print(board)
        print("player o is the winner!!!!")
        break

    if board[0][2] == "o" and board[1][1] == "o" and board[2][0] == "o":
        print(board)
        print("player o is the winner!!!!")
        break
    for i in range(3):
        if board[i-1][i-1] == "o":
            f += 1
    if f == 3:
        print(board)
        print("player o is the winner!!!!")
        break
    else:
        f = 0

    for i in range(3):
      for j in range(3):
         if board[i][j] == "_":
            k += 1
    if k == 0:
        print(board)
        print("! DRAW !")
        break
# Out:
# you are [x]
# select the row:  1
# select the column:  1
# you are [o]
# select the row:  2
# select the column:  2
# you are [x]
# select the row:  3
# select the column:  3
# you are [o]
# select the row:  1
# select the column:  2
# you are [x]
# select the row:  1
# select the column:  3
# you are [o]
# select the row:  3
# select the column:  2
# player o is the winner!!!!

# %%
#Playing X-O With Computer

# %%
l = [["_","_","_"],
     ["_","_","_"],
     ["_","_","_"]]

board = np.array(l)

first = input("Who do you want to play first?\n1-me\n2-bot\n")
player = input("X or O? ")
player = player.lower()
if player == "x" and first == "me":
    k = 1
    while k > 0: 
        k = 0
        print(board)
        playerx_i = eval(input("select the row: "))
        playerx_j = eval(input("select the column: "))
        
        if board[playerx_i-1][playerx_j-1] == "_":
            board[playerx_i-1][playerx_j-1] = "x"
        else:
            playerxx_i = playerx_i
            playerxx_j = playerx_j
            while board[playerxx_i-1][playerxx_j-1] != "_":
                print("you can not put this here!")
                print(board)
                playerxx_i = eval(input("select another row: "))
                playerxx_j = eval(input("select another column: "))
                if board[playerxx_i-1][playerxx_j-1] == "_":
                    board[playerxx_i-1][playerxx_j-1] = "x"
                    break     
        if board[0][0] == "x" and board[1][0] == "x" and board[2][0] == "x":
            print(board)
            print("You win!")
            break
        if board[0][1] == "x" and board[1][1] == "x" and board[2][1] == "x":
            print(board)
            print("You win!")
            break
        if board[0][2] == "x" and board[1][2] == "x" and board[2][2] == "x":
            print(board)
            print("You win!")
            break
        if board[0][0] == "x" and board[0][1] == "x" and board[0][2] == "x":
            print(board)
            print("You win!")
            break
        if board[1][0] == "x" and board[1][1] == "x" and board[1][2] == "x":
            print(board)
            print("You win!")
            break
        if board[2][0] == "x" and board[2][1] == "x" and board[2][2] == "x":
            print(board)
            print("You win!")
            break

        if board[0][2] == "x" and board[1][1] == "x" and board[2][0] == "x":
            print(board)
            print("You win!")
            break
        f = 0
        for i in range(3):
            if board[i-1][i-1] == "x":
                f += 1
        if f == 3:
            print(board)
            print("You win!")
            break
        else:
            f = 0

        for i in range(3):
          for j in range(3):
             if board[i][j] == "_":
                k += 1
        if k == 0:
            print(board)
            print("! DRAW !")
            break
#//////////////////////////////////////////////////////////////////
        a = np.random.randint(0,3,2)
        oi = 10
        for x in a:
            if oi == 10:
                oi = x
            else:
                oj = x
        if board[oi][oj] == "_":
            board[oi][oj] = "o"
        else:
            oii = oi
            ojj = oj
            while board[oii][ojj] != "_":
                a = np.random.randint(0,3,2)
                oii = 10
                for x in a:
                    if oii == 10:
                        oii = x
                    else:
                        ojj = x
                if board[oii][ojj] == "_":
                    board[oii][ojj] = "o"
                    break
        if board[0][0] == "o" and board[1][0] == "o" and board[2][0] == "o":
            print(board)
            print("You lost😂👉")
            break
        if board[0][1] == "o" and board[1][1] == "o" and board[2][1] == "o":
            print(board)
            print("You lost😂👉")
            break
        if board[0][2] == "o" and board[1][2] == "o" and board[2][2] == "o":
            print(board)
            print("You lost😂👉")
            break
        if board[0][0] == "o" and board[0][1] == "o" and board[0][2] == "o":
            print(board)
            print("You lost😂👉")
            break
        if board[1][0] == "o" and board[1][1] == "o" and board[1][2] == "o":
            print(board)
            print("You lost😂👉")
            break
        if board[2][0] == "o" and board[2][1] == "o" and board[2][2] == "o":
            print(board)
            print("You lost😂👉")
            break

        if board[0][2] == "o" and board[1][1] == "o" and board[2][0] == "o":
            print(board)
            print("You lost😂👉")
            break
        f = 0
        for i in range(3):
            if board[i-1][i-1] == "o":
                f += 1
        if f == 3:
            print(board)
            print("You lost😂👉")
            break
        else:
            f = 0

        for i in range(3):
          for j in range(3):
             if board[i][j] == "_":
                k += 1
        if k == 0:
            print(board)
            print("! DRAW !")
            break
#---------------------------------------------------------------------------
elif player == "x" and first == "bot":
    k = 1
    while k > 0: 
        k = 0
        a = np.random.randint(0,3,2)
        oi = 10
        for x in a:
            if oi == 10:
                oi = x
            else:
                oj = x
        if board[oi][oj] == "_":
            board[oi][oj] = "o"
        else:
            oii = oi
            ojj = oj
            while board[oii][ojj] != "_":
                a = np.random.randint(0,3,2)
                oii = 10
                for x in a:
                    if oii == 10:
                        oii = x
                    else:
                        ojj = x
                if board[oii][ojj] == "_":
                    board[oii][ojj] = "o"
                    break
        if board[0][0] == "o" and board[1][0] == "o" and board[2][0] == "o":
            print(board)
            print("You lost😂👉")
            break
        if board[0][1] == "o" and board[1][1] == "o" and board[2][1] == "o":
            print(board)
            print("You lost😂👉")
            break
        if board[0][2] == "o" and board[1][2] == "o" and board[2][2] == "o":
            print(board)
            print("You lost😂👉")
            break
        if board[0][0] == "o" and board[0][1] == "o" and board[0][2] == "o":
            print(board)
            print("You lost😂👉")
            break
        if board[1][0] == "o" and board[1][1] == "o" and board[1][2] == "o":
            print(board)
            print("You lost😂👉")
            break
        if board[2][0] == "o" and board[2][1] == "o" and board[2][2] == "o":
            print(board)
            print("You lost😂👉")
            break

        if board[0][2] == "o" and board[1][1] == "o" and board[2][0] == "o":
            print(board)
            print("You lost😂👉")
            break
        f = 0
        for i in range(3):
            if board[i-1][i-1] == "o":
                f += 1
        if f == 3:
            print(board)
            print("You lost😂👉")
            break
        else:
            f = 0

            for i in range(3):
              for j in range(3):
                 if board[i][j] == "_":
                    k += 1
            if k == 0:
                print(board)
                print("! DRAW !")
                break
#/////////////////////////////////////////////////////////////
        print(board)
        playerx_i = eval(input("select the row: "))
        playerx_j = eval(input("select the column: "))
        
        if board[playerx_i-1][playerx_j-1] == "_":
            board[playerx_i-1][playerx_j-1] = "x"
        else:
            playerxx_i = playerx_i
            playerxx_j = playerx_j
            while board[playerxx_i-1][playerxx_j-1] != "_":
                print("you can not put this here!")
                print(board)
                playerxx_i = eval(input("select another row: "))
                playerxx_j = eval(input("select another column: "))
                if board[playerxx_i-1][playerxx_j-1] == "_":
                    board[playerxx_i-1][playerxx_j-1] = "x"
                    break     
        if board[0][0] == "x" and board[1][0] == "x" and board[2][0] == "x":
            print(board)
            print("You win!")
            break
        if board[0][1] == "x" and board[1][1] == "x" and board[2][1] == "x":
            print(board)
            print("You win!")
            break
        if board[0][2] == "x" and board[1][2] == "x" and board[2][2] == "x":
            print(board)
            print("You win!")
            break
        if board[0][0] == "x" and board[0][1] == "x" and board[0][2] == "x":
            print(board)
            print("You win!")
            break
        if board[1][0] == "x" and board[1][1] == "x" and board[1][2] == "x":
            print(board)
            print("You win!")
            break
        if board[2][0] == "x" and board[2][1] == "x" and board[2][2] == "x":
            print(board)
            print("You win!")
            break

        if board[0][2] == "x" and board[1][1] == "x" and board[2][0] == "x":
            print(board)
            print("You win!")
            break
        f = 0
        for i in range(3):
            if board[i-1][i-1] == "x":
                f += 1
        if f == 3:
            print(board)
            print("You win!")
            break
        else:
            f = 0

        for i in range(3):
          for j in range(3):
             if board[i][j] == "_":
                k += 1
        if k == 0:
            print(board)
            print("! DRAW !")
            break
#----------------------------------------------------------------------
elif player == "o" and first == "me":
    k = 1
    while k > 0: 
        k = 0
        print(board)
        playero_i = eval(input("select the row: "))
        playero_j = eval(input("select the column: "))
        
        if board[playero_i-1][playero_j-1] == "_":
            board[playero_i-1][playero_j-1] = "o"
        else:
            playeroo_i = playero_i
            playeroo_j = playero_j
            while board[playeroo_i-1][playeroo_j-1] != "_":
                print("you can not put this here!")
                print(board)
                playeroo_i = eval(input("select another row: "))
                playeroo_j = eval(input("select another column: "))
                if board[playeroo_i-1][playeroo_j-1] == "_":
                    board[playeroo_i-1][playeroo_j-1] = "o"
                    break     
        if board[0][0] == "o" and board[1][0] == "o" and board[2][0] == "o":
            print(board)
            print("You win!")
            break
        if board[0][1] == "o" and board[1][1] == "o" and board[2][1] == "o":
            print(board)
            print("You win!")
            break
        if board[0][2] == "o" and board[1][2] == "o" and board[2][2] == "o":
            print(board)
            print("You win!")
            break
        if board[0][0] == "o" and board[0][1] == "o" and board[0][2] == "o":
            print(board)
            print("You win!")
            break
        if board[1][0] == "o" and board[1][1] == "o" and board[1][2] == "o":
            print(board)
            print("You win!")
            break
        if board[2][0] == "o" and board[2][1] == "o" and board[2][2] == "o":
            print(board)
            print("You win!")
            break

        if board[0][2] == "o" and board[1][1] == "o" and board[2][0] == "o":
            print(board)
            print("You win!")
            break
        f = 0
        for i in range(3):
            if board[i-1][i-1] == "o":
                f += 1
        if f == 3:
            print(board)
            print("You win!")
            break
        else:
            f = 0

        for i in range(3):
          for j in range(3):
             if board[i][j] == "_":
                k += 1
        if k == 0:
            print(board)
            print("! DRAW !")
            break
#///////////////////////////////////////////////////////////////
        a = np.random.randint(0,3,2)
        xi = 10
        for x in a:
            if xi == 10:
                xi = x
            else:
                xj = x
        if board[xi][xj] == "_":
            board[xi][xj] = "x"
        else:
            xii = xi
            xjj = xj
            while board[xii][xjj] != "_":
                a = np.random.randint(0,3,2)
                xii = 10
                for x in a:
                    if xii == 10:
                        xii = x
                    else:
                        xjj = x
                if board[xii][xjj] == "_":
                    board[xii][xjj] = "x"
                    break
        if board[0][0] == "x" and board[1][0] == "x" and board[2][0] == "x":
            print(board)
            print("You lost😂👉")
            break
        if board[0][1] == "x" and board[1][1] == "x" and board[2][1] == "x":
            print(board)
            print("You lost😂👉")
            break
        if board[0][2] == "x" and board[1][2] == "x" and board[2][2] == "x":
            print(board)
            print("You lost😂👉")
            break
        if board[0][0] == "x" and board[0][1] == "x" and board[0][2] == "x":
            print(board)
            print("You lost😂👉")
            break
        if board[1][0] == "x" and board[1][1] == "x" and board[1][2] == "x":
            print(board)
            print("You lost😂👉")
            break
        if board[2][0] == "x" and board[2][1] == "x" and board[2][2] == "x":
            print(board)
            print("You lost😂👉")
            break

        if board[0][2] == "x" and board[1][1] == "x" and board[2][0] == "x":
            print(board)
            print("You lost😂👉")
            break
        f = 0
        for i in range(3):
            if board[i-1][i-1] == "x":
                f += 1
        if f == 3:
            print(board)
            print("You lost😂👉")
            break
        else:
            f = 0

        for i in range(3):
          for j in range(3):
             if board[i][j] == "_":
                k += 1
        if k == 0:
            print(board)
            print("! DRAW !")
            break
#------------------------------------------------------------------ 
elif player == "o" and first == "bot":
    k = 1
    while k > 0: 
        k = 0
        a = np.random.randint(0,3,2)
        xi = 10
        for x in a:
            if xi == 10:
                xi = x
            else:
                xj = x
        if board[xi][xj] == "_":
            board[xi][xj] = "x"
        else:
            xii = xi
            xjj = xj
            while board[xii][xjj] != "_":
                a = np.random.randint(0,3,2)
                xii = 10
                for x in a:
                    if xii == 10:
                        xii = x
                    else:
                        xjj = x
                if board[xii][xjj] == "_":
                    board[xii][xjj] = "x"
                    break
        if board[0][0] == "x" and board[1][0] == "x" and board[2][0] == "x":
            print(board)
            print("You lost😂👉")
            break
        if board[0][1] == "x" and board[1][1] == "x" and board[2][1] == "x":
            print(board)
            print("You lost😂👉")
            break
        if board[0][2] == "x" and board[1][2] == "x" and board[2][2] == "x":
            print(board)
            print("You lost😂👉")
            break
        if board[0][0] == "x" and board[0][1] == "x" and board[0][2] == "x":
            print(board)
            print("You lost😂👉")
            break
        if board[1][0] == "x" and board[1][1] == "x" and board[1][2] == "x":
            print(board)
            print("You lost😂👉")
            break
        if board[2][0] == "x" and board[2][1] == "x" and board[2][2] == "x":
            print(board)
            print("You lost😂👉")
            break

        if board[0][2] == "x" and board[1][1] == "x" and board[2][0] == "x":
            print(board)
            print("You lost😂👉")
            break
        f = 0
        for i in range(3):
            if board[i-1][i-1] == "x":
                f += 1
        if f == 3:
            print(board)
            print("You lost😂👉")
            break
        else:
            f = 0

            for i in range(3):
              for j in range(3):
                 if board[i][j] == "_":
                    k += 1
            if k == 0:
                print(board)
                print("! DRAW !")
                break
#////////////////////////////////////////////////////////////////
        print(board)
        playero_i = eval(input("select the row: "))
        playero_j = eval(input("select the column: "))
        
        if board[playero_i-1][playero_j-1] == "_":
            board[playero_i-1][playero_j-1] = "o"
        else:
            playeroo_i = playero_i
            playeroo_j = playero_j
            while board[playeroo_i-1][playeroo_j-1] != "_":
                print("you can not put this here!")
                print(board)
                playeroo_i = eval(input("select another row: "))
                playeroo_j = eval(input("select another column: "))
                if board[playeroo_i-1][playeroo_j-1] == "_":
                    board[playeroo_i-1][playeroo_j-1] = "o"
                    break     
        if board[0][0] == "o" and board[1][0] == "o" and board[2][0] == "o":
            print(board)
            print("You win!")
            break
        if board[0][1] == "o" and board[1][1] == "o" and board[2][1] == "o":
            print(board)
            print("You win!")
            break
        if board[0][2] == "o" and board[1][2] == "o" and board[2][2] == "o":
            print(board)
            print("You win!")
            break
        if board[0][0] == "o" and board[0][1] == "o" and board[0][2] == "o":
            print(board)
            print("You win!")
            break
        if board[1][0] == "o" and board[1][1] == "o" and board[1][2] == "o":
            print(board)
            print("You win!")
            break
        if board[2][0] == "o" and board[2][1] == "o" and board[2][2] == "o":
            print(board)
            print("You win!")
            break

        if board[0][2] == "o" and board[1][1] == "o" and board[2][0] == "o":
            print(board)
            print("You win!")
            break
        f = 0
        for i in range(3):
            if board[i-1][i-1] == "o":
                f += 1
        if f == 3:
            print(board)
            print("You win!")
            break
        else:
            f = 0

        for i in range(3):
          for j in range(3):
             if board[i][j] == "_":
                k += 1
        if k == 0:
            print(board)
            print("! DRAW !")
            break
# Out:
# Who do you want to play first?
# 1-me
# 2-bot
#  bot
# X or O?  x
# [['o' '_' '_']
#  ['_' '_' '_']
#  ['_' '_' '_']]
# select the row:  1
# select the column:  3
# [['o' '_' 'x']
#  ['o' '_' '_']
#  ['_' '_' '_']]
# select the row:  1
# select the column:  2
# [['o' 'x' 'x']
#  ['o' 'o' '_']
#  ['_' '_' '_']]
# select the row:  3
# select the column:  2
# [['o' 'x' 'x']
#  ['o' 'o' 'o']
#  ['_' 'x' '_']]
# You lost😂👉
